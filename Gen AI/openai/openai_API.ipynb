# %% [markdown]
# # Using the openAI API

# %%
import openai

# %% [markdown]
# ## What is OpenAI API
#
#  This OpenAI API has been designed to provide developers with seamless access to state of the art, pre trained, artificial intelligence models like gpt-3 gpt-4, dall E , whisper, embeddings etc so by using this openai api we can integrate cutting edge ai capabilities into our applications regardless the programming language.
#
#  Using this openai API we can unlock the advance functionalities and we can enhance the intelligence and performance of our application.

# %% [markdown]
# ## Generate the OpenaiAPI Key
# sk-proj-267fQB1fva1keKZCMiklT3BlbkFJGmlVZNbElQofUKXhu4jx

# %%
all_models = openai.models.list()

# %%
list(all_models)
# Out:
# [Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'),
#  Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'),
#  Model(id='davinci-002', created=1692634301, object='model', owned_by='system'),
#  Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-16k', created=1683758102, object='model', owned_by='openai-internal'),
#  Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'),
#  Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-instruct-0914', created=1694122472, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-instruct', created=1692901427, object='model', owned_by='system'),
#  Model(id='tts-1', created=1681940951, object='model', owned_by='openai-internal'),
# ...

# %%
import pandas as pd
pd.DataFrame(list(all_models))
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_14392\127861992.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                                     0                      1                2  \
# 0                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 1                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 2                   (id, davinci-002)  (created, 1692634301)  (object, model)
# 3                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 4             (id, gpt-3.5-turbo-16k)  (created, 1683758102)  (object, model)
# ...

# %%
from openai import OpenAI

client = OpenAI(
    api_key = os.environ.get("OPENAI_API")
)

completion = client.chat.completions.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the fastest car?"}
    ]
)
print(completion.choices[0].message.content)
